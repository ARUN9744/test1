# %%
import pandas as pd

df = pd.read_csv('Real estate.csv')
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 0       24.98298     121.54024                        37.9
# 1       24.98034     121.53951                        42.2
# 2       24.98746     121.54391                        47.3
# 3       24.98746     121.54391                        54.8
# 4       24.97937     121.54245                        43.1
# ..           ...           ...                         ...
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# 411     24.97923     121.53986                        40.6
# 412     24.96674     121.54067                        52.5
# 413     24.97433     121.54310                        63.9
#
# [414 rows x 8 columns]

# %%
y = df['Y house price of unit area']
y
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: Y house price of unit area, Length: 414, dtype: float64

# %%
X = df.drop('Y house price of unit area', axis=1)
X
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude
# 0       24.98298     121.54024
# 1       24.98034     121.53951
# 2       24.98746     121.54391
# 3       24.98746     121.54391
# 4       24.97937     121.54245
# ..           ...           ...
# 409     24.94155     121.50381
# 410     24.97433     121.54310
# 411     24.97923     121.53986
# 412     24.96674     121.54067
# 413     24.97433     121.54310
#
# [414 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# %%
X_train
# Out:
#       No  X1 transaction date  X2 house age  \
# 272  273             2012.750          13.0
# 390  391             2013.500          32.8
# 69    70             2012.833          12.5
# 325  326             2013.083          36.6
# 199  200             2013.417          18.2
# ..   ...                  ...           ...
# 343  344             2013.000          33.5
# 359  360             2013.500           5.6
# 323  324             2013.417          28.6
# 280  281             2013.250           2.3
# 8      9             2013.500          31.7
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 272                                492.2313                                5
# 390                                377.8302                                9
# 69                                 561.9845                                5
# 325                                488.8193                                8
# 199                                451.6419                                8
# ..                                      ...                              ...
# 343                                563.2854                                8
# 359                               2408.9930                                0
# 323                                197.1338                                6
# 280                                184.3302                                6
# 8                                 5512.0380                                1
#
#      X5 latitude  X6 longitude
# 272     24.96515     121.53737
# 390     24.97151     121.54350
# 69      24.98746     121.54391
# 325     24.97015     121.54494
# 199     24.96945     121.54490
# ..           ...           ...
# 343     24.98223     121.53597
# 359     24.95505     121.55964
# 323     24.97631     121.54436
# 280     24.96581     121.54086
# 8       24.95095     121.48458
#
# [331 rows x 7 columns]

# %%
X_test
# Out:
#       No  X1 transaction date  X2 house age  \
# 121  122             2013.500          13.6
# 353  354             2013.500           4.1
# 96    97             2013.417           6.4
# 43    44             2012.750          34.4
# 125  126             2013.167           1.1
# ..   ...                  ...           ...
# 157  158             2013.250          16.1
# 184  185             2012.750          14.1
# 129  130             2013.417          38.5
# 357  358             2013.417           0.0
# 241  242             2013.500          13.7
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 121                               492.23130                                5
# 353                              2147.37600                                3
# 96                                 90.45606                                9
# 43                                512.78710                                6
# 125                               193.58450                                6
# ..                                      ...                              ...
# 157                               815.93140                                4
# 184                              2615.46500                                0
# 129                               216.83290                                7
# 357                               338.96790                                9
# 241                               250.63100                                7
#
#      X5 latitude  X6 longitude
# 121     24.96515     121.53737
# 353     24.96299     121.51284
# 96      24.97433     121.54310
# 43      24.98748     121.54301
# 125     24.96571     121.54089
# ..           ...           ...
# 157     24.97886     121.53464
# 184     24.95495     121.56174
# 129     24.98086     121.54162
# 357     24.96853     121.54413
# 241     24.96606     121.54297
#
# [83 rows x 7 columns]

# %% [markdown]
# # # linear model

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_lr_train_pred = lr.predict(X_train)

# %%
y_lr_train_pred
# Out:
# array([39.64044726, 44.02194153, 45.19955461, 38.85221322, 46.27197973,
#        46.94579946, 42.4960859 , 47.4250247 , 24.51498568, 39.69646041,
#        51.51878186, 43.9187444 , 40.29660673, 47.99308569, 42.92532083,
#        43.74101634,  9.00467153, 40.99250699, 40.26988864, 48.5448233 ,
#        41.59319331, 11.88261866, 34.63799189, 43.46147033, 38.60795667,
#        44.02879574, 34.44645308, 42.36880806, 36.40356296, 42.41319707,
#        49.01191491, 36.43597907, 47.86778492, 34.72081181, 38.8562289 ,
#        32.66548526, 35.1162038 , 31.06760736, 44.38730008, 14.13545904,
#        45.31885913, 42.04725328, 36.99713368, 40.51092015, 40.55095997,
#        35.04413314, 38.27307907, 47.73712532, 53.23019235, 41.33904471,
#        37.54936897, 32.6970736 , 50.04689927, 42.97663695, 40.70534091,
#        46.37871785, 43.10553961, 33.59315504, 48.19483716, 46.30860927,
#        37.57220068, 40.45649635, 34.49149531, 34.01878708, 54.71983574,
#        29.77734094, 39.73744828, 43.73259056, 42.86983505, 34.07992806,
#        33.368726  , 46.72147524, 17.65809464, 43.86512033, 45.23438972,
#        35.30845029, 37.19085745, 13.23723566, 31.70810004, 42.0772283 ,
#        41.73701933, 15.27574424, 47.09590178, 31.23005911, 13.64617205,
#        28.11560841, 32.21740805, 45.25132123, 21.70992663, 31.67610278,
#        50.95288865, 35.43675696, 41.34469243, 42.92839425, 35.35680365,
#        38.74343039, 53.42308668, 49.22351809, 39.31728473, 41.7700379 ,
#        35.8504802 , 41.14067657, 17.28969258, 47.95007931, 33.11753226,
#        46.09244194, 48.93909165, 39.59195081, 30.22786364, 44.87803696,
#        13.20269819, 45.21988626, 25.14899728, 44.36930779, 37.28612595,
#        48.42141632, 36.15751756, 48.97153915, 37.98494631, 38.97972268,
#        49.90994873, 30.33556201, 31.84620325, 53.7274414 , 43.71280509,
#        28.7181334 , 34.79499356, 31.49279538, 13.99837777, 46.86936075,
#        13.64927331, 25.10252755, 54.23034203, 43.31861756, 24.01895453,
#        29.21445853, 44.34047126, 31.38162137, 37.17733989, 34.27680708,
#        38.96948183, 38.76329509, 41.76798845, 40.10749719, 17.96891075,
#        43.61795742, 24.05588897, 29.35309144, 38.71958272, 13.26514919,
#        33.27616873, 19.98342815, 36.46407391, 39.8967046 , 40.31910159,
#        54.47253541, 36.13525757, 39.74453856, 45.80811846, 26.97166535,
#        47.16101744, 37.52826194, 15.55405922, 42.05757143, 47.31237647,
#        47.44664292, 45.74970056, 34.48036441, 33.20971187, 40.3264095 ,
#        46.48127913, 39.25506989, 31.87037344, 43.72369544, 45.24277408,
#        43.57464649, 30.69658446, 41.47407256, 41.00606338, 51.83488724,
#        46.83192103, 47.60746467, 32.10045476, 47.92620999, 31.25158962,
#        39.34199873, 49.23228172, 49.97464242, 37.97211031, 45.97579953,
#        42.85755064, 46.95549803, 46.81628888, 36.11919892, 51.89615566,
#         7.35585853, 34.19478761, 46.87950797, 45.48051242, 46.25041224,
#        33.91449628, 43.87823081, 31.87495999, 42.50909897, 21.25804044,
#        43.537617  , 52.23825555, 47.10245882])

# %%
from sklearn.metrics import mean_squared_error, r2_score

lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
print('LR MSE (Train): ', lr_train_mse)
print('LR R2 (Train): ', lr_train_r2)
print('LR MSE (Test): ', lr_test_mse)
print('LR R2 (Test): ', lr_test_r2)
# Out:
# LR MSE (Train):  84.13499497686715
# LR R2 (Train):  0.5635442787603557
# LR MSE (Test):  48.94787812582623
# LR R2 (Test):  0.6721060393571074

# %%
lr_results = pd.DataFrame(['Linear regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']

# %%
lr_results
# Out:
#               Method Training MSE Training R2   Test MSE   Test R2
# 0  Linear regression    84.134995    0.563544  48.947878  0.672106

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %%
y_rf_train_pred = rf.predict(X_train)
y_rf_test_pred = rf.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
rf_results
# Out:
#           Method Training MSE Training R2   Test MSE   Test R2
# 0  Random forest    68.530965    0.644491  40.851949  0.726339

# %%
df_models = pd.concat([lr_results, rf_results], axis=0)

# %%
df_models.reset_index(drop=True)
# Out:
#               Method Training MSE Training R2   Test MSE   Test R2
# 0  Linear regression    84.134995    0.563544  48.947878  0.672106
# 1      Random forest    68.530965    0.644491  40.851949  0.726339

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.scatter(x=y_train, y=y_lr_train_pred, c="#7CAE00" ,alpha=0.3)

z = np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(z)

plt.plot(y_train, p(y_train), '#F8766D')
plt.ylabel('Predict LogS')
plt.xlabel('Experimental LogS')
# Out:
# Text(0.5, 0, 'Experimental LogS')
